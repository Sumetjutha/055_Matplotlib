# %%
import matplotlib.pyplot as plt

# %%
product1 = [10,20,30,40,50]
product2 = [15,30,10,20,60]
month = [1,2,3,4,5]

# %%
plt.plot(month,product1,color="salmon",marker="s",linestyle='--')
plt.plot(month,product2,marker="o",linestyle='-.')
data = {'size':20,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

plt.title("Top Sale 2020",data)
# Out:
# Text(0.5, 1.0, 'Top Sale 2020')

# %%
plt.plot(month,product1,color="salmon",marker="s",linestyle='--')
plt.plot(month,product2,marker="o",linestyle='-.')
data = {'size':20,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":25}
plt.title("Top Sale 2020",config)
# Out:
# Text(0.5, 1.0, 'Top Sale 2020')

# %%
plt.plot(month,product1,color="salmon",marker="s",linestyle='--')
plt.plot(month,product2,marker="o",linestyle='-.')
data = {'size':20,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":25}
plt.title("Top Sale 2020",config,loc="left")
# Out:
# Text(0.0, 1.0, 'Top Sale 2020')

# %%
plt.plot(month,product1,color="salmon",marker="s",linestyle='--')
plt.plot(month,product2,marker="o",linestyle='-.')
data = {'size':20,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":25}
plt.title("Top Sale 2020",config,loc="right")
# Out:
# Text(1.0, 1.0, 'Top Sale 2020')
