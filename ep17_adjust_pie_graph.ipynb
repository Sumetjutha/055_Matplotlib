# %%
import matplotlib.pyplot as plt

# %%
student = [10,20,40,30,60]

# %%
course = ["PHP","Java","Python","C#","NodeJS"]

# %%
color = ["lightgrey","lightpink","lightblue","lightyellow","lightgreen"]
exp = [0.2,0,0,0.2,0.2]
plt.pie(student,labels=course,autopct="%.2f%%",colors=color,explode=exp,startangle=45)
# Out:
# ([<matplotlib.patches.Wedge at 0x214af1d51f0>,
# ...
#  [Text(0.722241302925483, 1.080910495993309, 'PHP'),
#   Text(6.735557395310444e-17, 1.1, 'Java'),
#   Text(-1.0162674857624154, 0.4209517756015989, 'Python'),
#   Text(-0.7222413029254828, -1.080910495993309, 'C#'),
#   Text(1.2010433922646726, -0.49748846207461755, 'NodeJS')],
#  [Text(0.44445618641568185, 0.6651756898420362, '6.25%'),
#   Text(3.6739403974420595e-17, 0.6, '12.50%'),
#   Text(-0.5543277195067721, 0.22961005941905394, '25.00%'),
#   Text(-0.44445618641568174, -0.6651756898420362, '18.75%'),
#   Text(0.7391036260090291, -0.3061467458920723, '37.50%')])
