# %%
import matplotlib.pyplot as plt

# %%
product1 = [10,20,30,40,50]
product2 = [15,30,10,20,60]
month = [1,2,3,4,5]

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize=15)

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="medium")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="large")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="xx-large")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="xx-small")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="x-small")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="small")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0,fontsize="medium")
