# %%
import matplotlib.pyplot as plt

# %%
course = ["Python","Java","C#"]

# %%
score = [80,75,50]

# %%
plt.bar(course, score)
plt.xlabel("Course")
plt.ylabel("Score")
plt.title("Score Midterm")
# Out:
# Text(0.5, 1.0, 'Score Midterm')
