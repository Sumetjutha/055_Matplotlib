# %%
import matplotlib.pyplot as plt

# %%
product1 = [10,20,30,40,50]
product2 = [15,30,10,20,60]
month = [1,2,3,4,5]

# %%
plt.plot(month,product1,color="salmon",marker="v")
plt.plot(month,product2,color="magenta",marker="<")
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
