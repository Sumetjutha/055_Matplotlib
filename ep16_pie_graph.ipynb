# %%
import matplotlib.pyplot as plt

# %%
student = [10,20,40,30,60]

# %%
course = ["PHP","Java","Python","C#","NodeJS"]

# %%
plt.pie(student,labels=course,autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1b3d588eb20>,
#   <matplotlib.patches.Wedge at 0x1b3d5914fa0>,
#   <matplotlib.patches.Wedge at 0x1b3d5914310>,
#   <matplotlib.patches.Wedge at 0x1b3d589bb20>,
#   <matplotlib.patches.Wedge at 0x1b3d58a4160>],
#  [Text(1.0788638084435536, 0.2145993542177411, 'PHP'),
#   Text(0.7778174593052024, 0.7778174593052024, 'Java'),
#   Text(-0.42095177560159874, 1.0162674857624154, 'Python'),
#   Text(-1.0788638084435536, -0.2145993542177412, 'C#'),
#   Text(0.420951775601599, -1.0162674857624154, 'NodeJS')],
#  [Text(0.5884711682419382, 0.11705419320967694, '6.2%'),
#   Text(0.4242640687119285, 0.4242640687119285, '12.5%'),
#   Text(-0.22961005941905382, 0.5543277195067721, '25.0%'),
#   Text(-0.5884711682419382, -0.11705419320967701, '18.8%'),
#   Text(0.229610059419054, -0.554327719506772, '37.5%')])
