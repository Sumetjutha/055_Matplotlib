# %%
import matplotlib.pyplot as plt

# %%
product1 = [10,20,30,40,50]
product2 = [15,30,10,20,60]
month = [1,2,3,4,5]

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="best")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="upper right")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="lower right")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="center right")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="center")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="center left")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc="lower left")

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=3)

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=4)

# %%
plt.plot(month,product1,'gs--')
plt.plot(month,product2,'r*-.')

data = {'size':12,'color':"red",'backgroundcolor':'yellow'}

plt.xlabel("Month",data)
plt.ylabel("Sales",data)

config = {"color":"blue","size":15}
plt.title("Top Sale 2020",config)

plt.legend(["Mouse","Keyboard"],loc=0)
