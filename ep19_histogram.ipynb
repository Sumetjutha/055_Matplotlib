# %%
import matplotlib.pyplot as plt

# %%
age = [10,15,20,15,25,10,20,34,15,10,20,25,30,40,20,10,15,20,30,15,15]

# %%
plt.xlabel("Age")
plt.ylabel("Count")
plt.hist(age)
plt.legend(["Age"])
plt.title("Total Age")
# Out:
# Text(0.5, 1.0, 'Total Age')
